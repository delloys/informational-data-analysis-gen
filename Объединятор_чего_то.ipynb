# %% [markdown]
# <a href="https://colab.research.google.com/github/delloys/informational-data-analysis-gen/blob/main/%D0%9E%D0%B1%D1%8A%D0%B5%D0%B4%D0%B8%D0%BD%D1%8F%D1%82%D0%BE%D1%80_%D1%87%D0%B5%D0%B3%D0%BE_%D1%82%D0%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 12.8 MB/s eta 0:00:00
# ...

# %%
from traitlets.traitlets import observe_compat
import math
import openpyxl
import numpy as np
import pandas as pd
import xlsxwriter

# %% [markdown]
# Union2.xlsx - ЧПД 2, вывод в test2.xlsx

# %%
#@title


#В Union2.xlsx три листа на каждом листе Иб ЧПД № периода ЗДП НГ и ВГ для одного признака и одного ЧПД(этот код для двух)


workbook = xlsxwriter.Workbook('test2.xlsx')
worksheet = workbook.add_worksheet()


red = workbook.add_format({ 'color': 'red'})

cell_format = workbook.add_format()
cell_format.set_bottom(2)
cell_format.set_left(1)
cell_format.set_right(1)
cell_format.set_align('center')
cell_format.set_align('vcenter')
cell_format.set_bg_color('#CCECFF')

cell_format_thin = workbook.add_format()
cell_format_thin.set_bottom(1)
cell_format_thin.set_left(1)
cell_format_thin.set_right(1)
cell_format_thin.set_align('center')
cell_format_thin.set_align('vcenter')
cell_format_thin.set_bg_color('#CCECFF')

cell_format_green_thin = workbook.add_format()
cell_format_green_thin.set_bottom(1)
cell_format_green_thin.set_left(1)
cell_format_green_thin.set_right(1)
cell_format_green_thin.set_align('center')
cell_format_green_thin.set_align('vcenter')
cell_format_green_thin.set_bg_color('#92D050')

cell_format_green = workbook.add_format()
cell_format_green.set_bottom(2)
cell_format_green.set_left(1)
cell_format_green.set_right(1)
cell_format_green.set_align('center')
cell_format_green.set_align('vcenter')
cell_format_green.set_bg_color('#92D050')

df1 = pd.read_excel('Union2.xlsx', sheet_name='Лист1',dtype = {'А': str})
df2 = pd.read_excel('Union2.xlsx', sheet_name='Лист2',dtype = {'А': str})
df3 = pd.read_excel('Union2.xlsx', sheet_name='Лист3',dtype = {'А': str})
num_of_CHPD = df1['ЧПД'][0]
n1 = df1['А'].count()
n2 = df2['А'].count()
n3 = df3['А'].count()
f=[]
f1 = []
o=1
flag = True
type(df1['ИБ'][0])

for i in range(0,n1):
    for j in range(0,n2):
        for p1 in range(0,int(num_of_CHPD)):
            split1=df1['ЗДП'][(i* num_of_CHPD)+p1].split("v")
            split2 = df2['ЗДП'][(j* num_of_CHPD)+p1].split("v")
            for item in split2: 
                   if item not in split1: 
                         split1.append(item)
            f.append(split1)
        
        print('\n')
        print(f[0],'==Первая сумма==',f[1]) #Значения для периода перввой суммы

        full_data1 = 'v'.join(f[0])
        full_data2 = 'v'.join(f[1])
        check_merge = 0
        # Для 3 и более периодов необходимо продублировать следующий for для всех пар f[i] f[i+1] до f[3] f[4], так чтобы количество внешних циклов for было на 1 меньше числа периодов
        for a in range(0,len(f[0])):
             for b in range(0,len(f[1])):
                 if f[0][a]==f[1][b]:
                      if check_merge !=1:
                        check_merge = 1
                        text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])

                        pp = 'A'+str(o*int(num_of_CHPD)-1)+':A' + str((o*int(num_of_CHPD)))
                        worksheet.merge_range(pp,text,cell_format)
                        pp = 'B'+str(o*int(num_of_CHPD)-1)+':B' + str((o*int(num_of_CHPD)))
                        worksheet.merge_range(pp,' - ',cell_format)

                        worksheet.write(o*int(num_of_CHPD)-2,2,'1',cell_format_thin)
                        worksheet.write(o*int(num_of_CHPD)-1,2,'2',cell_format)

                      check_str = f[0][a]
                      check_data1 = full_data1.partition(check_str)
                      check_data2 = full_data2.partition(check_str)
                      worksheet.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                      worksheet.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                      if check_data1[0] =='':
                        if check_data1[2] == '':
                          worksheet.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data1[1],cell_format_thin)
                        else:
                          worksheet.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data1[1],check_data1[2],cell_format_thin)
                        if check_data2[0] == '':
                          if check_data2[2] == '':
                            worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data2[1],cell_format)
                          else:
                            worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data2[1],check_data2[2],cell_format)
                        else:
                          if check_data2[2] == '':
                            worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,check_data2[0],red,check_data2[1],cell_format)
                          else:
                            worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format)
                      else:
                        if check_data1[2] == '':
                          worksheet.write_rich_string(o*int(num_of_CHPD)-2,3,check_data1[0],red,check_data1[1],cell_format_thin)
                        else:
                          worksheet.write_rich_string(o*int(num_of_CHPD)-2,3,check_data1[0],red,check_data1[1],check_data1[2],cell_format_thin)
                        if check_data2[0] == '':
                          worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data2[1],check_data2[2],cell_format)
                        else:
                          worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format)

                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[0][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
                      #o += 1
        f1 = f.copy()
        check_merge = 0
        get_len_n3 = 0
        if flag:#Если первая сумма подошла
              for k in range(0,n3):
                          get_len_n3 +=1
                          if check_merge != 1:
                            #check_merge = 1
                            text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                            text_sum2 = str(df3['ИБ'][0]) + ' А' + str(df3['А'][k*num_of_CHPD])

                            pp = 'A'+str(o*int(num_of_CHPD)-1)+':A' + str((o*int(num_of_CHPD)))
                            worksheet.merge_range(pp,text,cell_format)
                            pp = 'B'+str(o*int(num_of_CHPD)-1)+':B' + str((o*int(num_of_CHPD)))
                            worksheet.merge_range(pp,text_sum2,cell_format)

                          worksheet.write(o*int(num_of_CHPD)-2,2,'1',cell_format_green_thin)
                          worksheet.write(o*int(num_of_CHPD)-1,2,'2',cell_format_green)
                          worksheet.write(o*int(num_of_CHPD)-2,4,'',cell_format_green_thin)
                          worksheet.write(o*int(num_of_CHPD)-1,4,'',cell_format_green)
                          worksheet.write(o*int(num_of_CHPD)-2,5,'',cell_format_green_thin)
                          worksheet.write(o*int(num_of_CHPD)-1,5,'',cell_format_green)

                          print(df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD], '====1ая подошла')
                          for p1 in range(0,int(num_of_CHPD)):
                              #f = f1.copy()
                              split3= df3['ЗДП'][(k* num_of_CHPD)+p1].split("v")
                              for item in range(0,len(f[p1])): 
                                    if f[p1][item] not in split3: 
                                          split3.append(f[p1][item])
                              #f[p1] = []
                              f[p1] = split3.copy()
                              full_data1 = 'v'.join(f[p1])
                              if p1 == 0:
                                worksheet.write(o*int(num_of_CHPD)-2,3,full_data1,cell_format_green_thin)
                              else:
                                worksheet.write(o*int(num_of_CHPD)-1,3,full_data1,cell_format_green)
                              print(f[p1],' ppp ', p1+1)#Здесь находятся значения для периода для двух сумм, номер периода находится в p1+1
                          z = 0
                          # print(f[0],'=====',f[1]) #Значения для периода перввой суммы
                          # Для 3 и более периодов необходимо продублировать следующий for для всех пар f[i] f[i+1] до f[3] f[4], так чтобы количество внешних циклов for было на 1 меньше числа периодов(почти тоже самое что и сверху)
                          for a in range(0,len(f[0])):
                              for b in range(0,len(f[1])):
                                  if f[0][a]==f[1][b]:
                                        z = 1

                                        worksheet.write(o*int(num_of_CHPD)-2,2,'1',cell_format_thin)
                                        worksheet.write(o*int(num_of_CHPD)-1,2,'2',cell_format)
                                        worksheet.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                        worksheet.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                                        worksheet.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                        worksheet.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                                        full_data1 = 'v'.join(f[0])
                                        full_data2 = 'v'.join(f[1])

                                        check_str = f[0][a]
                                        print(check_str, ' ch_str')
                                        check_data1 = full_data1.partition(check_str)
                                        print(check_data1,' ch_d1')
                                        check_data2 = full_data2.partition(check_str)
                                        print(check_data2,' ch_d2 fd2', full_data2)

                                        if check_data1[0] =='':
                                          if check_data1[2] == '':
                                            worksheet.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data1[1],cell_format_thin)
                                          else:
                                            worksheet.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data1[1],check_data1[2],cell_format_thin)
                                          if check_data2[0] == '':
                                            if check_data2[2] == '':
                                              worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data2[1],cell_format)
                                            else:
                                              worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data2[1],check_data2[2],cell_format)
                                          else:
                                            if check_data2[2] == '':
                                              worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,check_data2[0],red,check_data2[1],cell_format)
                                            else:
                                              worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format)
                                        else:
                                          if check_data1[2] == '':
                                            worksheet.write_rich_string(o*int(num_of_CHPD)-2,3,check_data1[0],red,check_data1[1],cell_format_thin)
                                          else:
                                            worksheet.write_rich_string(o*int(num_of_CHPD)-2,3,check_data1[0],red,check_data1[1],check_data1[2],cell_format_thin)
                                          if check_data2[0] == '':
                                            worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data2[1],check_data2[2],cell_format)
                                          else:
                                            worksheet.write_rich_string(o*int(num_of_CHPD)-1,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format)
                                        #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                        print(f[0][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                                        print('\n')
                          o += 1
                          f = f1.copy()
        if get_len_n3 != n3:                  
          o +=1        
        f=[]
        flag = True
workbook.close()

# %% [markdown]
# Union3.xlsx - ЧПД 3, вывод в test3.xlsx

# %%
#@title

workbook = xlsxwriter.Workbook('test3.xlsx')
worksheet3 = workbook.add_worksheet('For3')

red = workbook.add_format({ 'color': 'red'})

cell_format = workbook.add_format()
cell_format.set_bottom(2)
cell_format.set_left(1)
cell_format.set_right(1)
cell_format.set_align('center')
cell_format.set_align('vcenter')
cell_format.set_bg_color('#CCECFF')

cell_format_thin = workbook.add_format()
cell_format_thin.set_bottom(1)
cell_format_thin.set_left(1)
cell_format_thin.set_right(1)
cell_format_thin.set_align('center')
cell_format_thin.set_align('vcenter')
cell_format_thin.set_bg_color('#CCECFF')

cell_format_green_thin = workbook.add_format()
cell_format_green_thin.set_bottom(1)
cell_format_green_thin.set_left(1)
cell_format_green_thin.set_right(1)
cell_format_green_thin.set_align('center')
cell_format_green_thin.set_align('vcenter')
cell_format_green_thin.set_bg_color('#92D050')

cell_format_green = workbook.add_format()
cell_format_green.set_bottom(2)
cell_format_green.set_left(1)
cell_format_green.set_right(1)
cell_format_green.set_align('center')
cell_format_green.set_align('vcenter')
cell_format_green.set_bg_color('#92D050')

df1 = pd.read_excel('Union3.xlsx', sheet_name='Лист1',dtype = {'А': str})
df2 = pd.read_excel('Union3.xlsx', sheet_name='Лист2',dtype = {'А': str})
df3 = pd.read_excel('Union3.xlsx', sheet_name='Лист3',dtype = {'А': str})
num_of_CHPD = df1['ЧПД'][0]
n1 = df1['А'].count()
n2 = df2['А'].count()
n3 = df3['А'].count()
f=[]
f1 = []
flag = True
o=1

type(df1['ИБ'][0])
for i in range(0,n1):
    for j in range(0,n2):
        print('ero o', o)
        # print(i,' ', j)
        for p1 in range(0,int(num_of_CHPD)):
            split1=df1['ЗДП'][(i* num_of_CHPD)+p1].split("v")
            split2 = df2['ЗДП'][(j* num_of_CHPD)+p1].split("v")
            for item in split2: 
                   if item not in split1: 
                         split1.append(item)
            f.append(split1)
        
        check_merge = 0
        print('\n')
        print(f[0],'==Первая сумма==',f[1],'===',f[2]) #Значения для периода перввой суммы
        # Для 3 и более периодов необходимо продублировать следующий for для всех пар f[i] f[i+1] до f[3] f[4], так чтобы количество внешних циклов for было на 1 меньше числа периодов
        for a in range(0,len(f[0])):
             for b in range(0,len(f[1])):
                 if f[0][a]==f[1][b]:
                      print('aaac,', check_merge)
                      check_merge = 1
                      text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])

                      pp = 'A'+str(o*int(num_of_CHPD)-2)+':A' + str((o*int(num_of_CHPD)))
                      worksheet3.merge_range(pp,text,cell_format)
                      pp = 'B'+str(o*int(num_of_CHPD)-2)+':B' + str((o*int(num_of_CHPD)))
                      worksheet3.merge_range(pp,' - ',cell_format)

                      worksheet3.write(o*int(num_of_CHPD)-3,2,'1',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-2,2,'2',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-1,2,'3',cell_format)
                      worksheet3.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                      worksheet3.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-1,5,'',cell_format)
                      
                      full_data1 = []
                      full_data2 = []
                      full_data3 = []
                      full_data1 = 'v'.join(f[0])
                      full_data2 = 'v'.join(f[1])
                      full_data3 = 'v'.join(f[2])

                      check_str = f[0][a]
                      check_data1 = full_data1.partition(check_str)
                      check_data2 = full_data2.partition(check_str)

                      print(check_str, ' ch_str ',check_data1,' ch_d1',check_data2, 'ch_d2')
                      print(str(full_data3), 'fdfdf', check_data1, 'ch_d1')

                      if check_data1[0] == '':
                        if check_data1[2] == '':
                          worksheet3.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data1[1],cell_format_thin)
                          worksheet3.write(o*int(num_of_CHPD)-1,3,full_data3,cell_format)
                        else:
                          worksheet3.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data1[1],check_data1[2],cell_format_thin)
                          worksheet3.write(o*int(num_of_CHPD)-1,3,full_data3,cell_format)
                        if check_data2[0] == '':
                          if check_data2[2] == '':
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data2[1],cell_format_thin)
                          else:
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data2[1],check_data2[2],cell_format_thin)
                        else:
                          if check_data2[2] == '':
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],cell_format_thin)
                          else:
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                      else:
                        if check_data1[2] == '':
                          worksheet3.write_rich_string(o*int(num_of_CHPD)-3,3,check_data1[0],red,check_data1[1],cell_format_thin)
                          worksheet3.write(o*int(num_of_CHPD)-1,3,full_data3,cell_format)
                        else:
                          worksheet3.write_rich_string(o*int(num_of_CHPD)-3,3,check_data1[0],red,check_data1[1],check_data1[2],cell_format_thin)
                          worksheet3.write(o*int(num_of_CHPD)-1,3,full_data3,cell_format)
                        if check_data2[0] == '':
                          if check_data2[2] == '':
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data2[1],cell_format_thin)
                          else:
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data2[1],check_data2[2],cell_format_thin)
                        else:
                          if check_data2[2] == '':
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],cell_format_thin)
                          else:
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)

                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[0][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
                      #o += 1
        for a in range(0,len(f[1])):
             for b in range(0,len(f[2])):
                 if f[1][a]==f[2][b]:
                      if check_merge != 1:
                        text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])

                        pp = 'A'+str(o*int(num_of_CHPD)-2)+':A' + str((o*int(num_of_CHPD)))
                        worksheet3.merge_range(pp,text,cell_format)
                        pp = 'B'+str(o*int(num_of_CHPD)-2)+':B' + str((o*int(num_of_CHPD)))
                        worksheet3.merge_range(pp,' - ',cell_format)
                        print('cc,', check_merge)
                        check_merge = 1
                        print('vv,', check_merge)
                      

                      worksheet3.write(o*int(num_of_CHPD)-3,2,'1',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-2,2,'2',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-1,2,'3',cell_format)
                      worksheet3.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                      worksheet3.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet3.write(o*int(num_of_CHPD)-1,5,'',cell_format)
                      
                      full_data1 = []
                      full_data2 = []
                      full_data3 = []
                      full_data0 = 'v'.join(f[0])
                      full_data1 = 'v'.join(f[1])
                      full_data2 = 'v'.join(f[2])

                      check_str = f[1][a]
                      check_data2 = full_data1.partition(check_str)
                      check_data3 = full_data2.partition(check_str)

                      print(check_str, ' ch_str ',check_data2,' ch_d2',check_data3, 'ch_d3')
                      #print(str(full_data2), 'fdfdf', check_data1, 'ch_d1')

                      if check_data2[0] == '':
                        if check_data2[2]=='':
                          worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data2[1],cell_format_thin)
                          worksheet3.write(o*int(num_of_CHPD)-3,3,full_data0,cell_format_thin)
                        else:
                          worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data2[1],check_data2[2],cell_format_thin)
                          worksheet3.write(o*int(num_of_CHPD)-3,3,full_data0,cell_format_thin)
                        if check_data3[0] == '':
                          if check_data3[2] == '':
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data3[1],cell_format)
                          else:
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data3[1],check_data3[2],cell_format)
                        else:
                          if check_data3[2] == '':
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,check_data3[0],red,check_data3[1],cell_format)
                          else:
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format)
                      else:
                        if check_data2[2]=='':
                          worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],cell_format_thin)
                          worksheet3.write(o*int(num_of_CHPD)-3,3,full_data0,cell_format_thin)
                        else:
                          worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                          worksheet3.write(o*int(num_of_CHPD)-3,3,full_data0,cell_format_thin)
                        if check_data3[0] == '':
                          if check_data3[2] == '':
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data3[1],cell_format)
                          else:
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data3[1],check_data3[2],cell_format)
                        else:
                          if check_data3[2] == '':
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,check_data3[0],red,check_data3[1],cell_format)
                          else:
                            worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format)
                      
                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[1][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
                      #o += 1
        get_len_n3 = 0
        f1 = f.copy()
        if flag:#Если первая сумма подошла
              for k in range(0,n3):
                            get_len_n3 +=1
                            if check_merge != 1:
                              #check_merge = 1
                              text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                              text_sum2 = str(df3['ИБ'][0]) + ' А' + str(df3['А'][k*num_of_CHPD])

                              pp = 'A'+str(o*int(num_of_CHPD)-2)+':A' + str((o*int(num_of_CHPD)))
                              worksheet3.merge_range(pp,text,cell_format)
                              pp = 'B'+str(o*int(num_of_CHPD)-2)+':B' + str((o*int(num_of_CHPD)))
                              worksheet3.merge_range(pp,text_sum2,cell_format)

                            print(df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD], '====1ая подошла')
                            for p1 in range(0,int(num_of_CHPD)):
                                #f = f1.copy()
                                split3= df3['ЗДП'][(k* num_of_CHPD)+p1].split("v")
                                for item in range(0,len(f[p1])): 
                                      if f[p1][item] not in split3: 
                                            split3.append(f[p1][item])
                                #f[p1] = []
                                f[p1] = split3.copy()
                                print(f[p1],' ', p1+1)#Здесь находятся значения для периода для двух сумм, номер периода находится в p1+1
                                
                                full_data1 = []
                                full_data1 = 'v'.join(f[p1])
                                if p1 == 0:
                                  worksheet3.write(o*int(num_of_CHPD)-3,2,'1',cell_format_green_thin)
                                  worksheet3.write(o*int(num_of_CHPD)-3,4,'',cell_format_green_thin)
                                  worksheet3.write(o*int(num_of_CHPD)-3,5,'',cell_format_green_thin)
                                  worksheet3.write(o*int(num_of_CHPD)-3,3,full_data1,cell_format_green_thin)
                                elif p1 == 1:
                                  worksheet3.write(o*int(num_of_CHPD)-2,2,'2',cell_format_green_thin)
                                  worksheet3.write(o*int(num_of_CHPD)-2,4,'',cell_format_green_thin)
                                  worksheet3.write(o*int(num_of_CHPD)-2,5,'',cell_format_green_thin)
                                  worksheet3.write(o*int(num_of_CHPD)-2,3,full_data1,cell_format_green_thin)
                                else:
                                  worksheet3.write(o*int(num_of_CHPD)-1,2,'3',cell_format_green)
                                  worksheet3.write(o*int(num_of_CHPD)-1,4,'',cell_format_green)
                                  worksheet3.write(o*int(num_of_CHPD)-1,5,'',cell_format_green)
                                  worksheet3.write(o*int(num_of_CHPD)-1,3,full_data1,cell_format_green)
                            
                            # print(f[0],'=====',f[1]) #Значения для периода перввой суммы
                            # Для 3 и более периодов необходимо продублировать следующий for для всех пар f[i] f[i+1] до f[3] f[4], так чтобы количество внешних циклов for было на 1 меньше числа периодов(почти тоже самое что и сверху)
                            for a in range(0,len(f[0])):
                                for b in range(0,len(f[1])):
                                    if f[0][a]==f[1][b]:

                                          worksheet3.write(o*int(num_of_CHPD)-3,2,'1',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-2,2,'2',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-1,2,'3',cell_format)
                                          worksheet3.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                                          worksheet3.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                                          full_data1 = []
                                          full_data2 = []
                                          full_data3 = []
                                          full_data1 = 'v'.join(f[0])
                                          full_data2 = 'v'.join(f[1])
                                          full_data3 = 'v'.join(f[2])

                                          check_str = f[0][a]
                                          check_data1 = full_data1.partition(check_str)
                                          check_data2 = full_data2.partition(check_str)

                                          print(check_str, ' ch_str ',check_data1,' ch_d1',check_data2, 'ch_d2')
                                          print(str(full_data3), 'fdfdf', check_data1, 'ch_d1')

                                          if check_data1[0] == '':
                                            if check_data1[2] == '':
                                              worksheet3.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data1[1],cell_format_thin)
                                              worksheet3.write(o*int(num_of_CHPD)-1,3,full_data3,cell_format)
                                            else:
                                              worksheet3.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data1[1],check_data1[2],cell_format_thin)
                                              worksheet3.write(o*int(num_of_CHPD)-1,3,full_data3,cell_format)
                                            if check_data2[0] == '':
                                              if check_data2[2] == '':
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data2[1],cell_format_thin)
                                              else:
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                            else:
                                              if check_data2[2] == '':
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],cell_format_thin)
                                              else:
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                                          else:
                                            if check_data1[2] == '':
                                              worksheet3.write_rich_string(o*int(num_of_CHPD)-3,3,check_data1[0],red,check_data1[1],cell_format_thin)
                                              worksheet3.write(o*int(num_of_CHPD)-1,3,full_data3,cell_format)
                                            else:
                                              worksheet3.write_rich_string(o*int(num_of_CHPD)-3,3,check_data1[0],red,check_data1[1],check_data1[2],cell_format_thin)
                                              worksheet3.write(o*int(num_of_CHPD)-1,3,full_data3,cell_format)
                                            if check_data2[0] == '':
                                              if check_data2[2] == '':
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data2[1],cell_format_thin)
                                              else:
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                            else:
                                              if check_data2[2] == '':
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],cell_format_thin)
                                              else:
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                                          #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                          print(f[0][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                                          
                            for a in range(0,len(f[1])):
                                for b in range(0,len(f[2])):
                                    if f[1][a]==f[2][b]:

                                          worksheet3.write(o*int(num_of_CHPD)-3,2,'1',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-2,2,'2',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-1,2,'3',cell_format)
                                          worksheet3.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                                          worksheet3.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                          worksheet3.write(o*int(num_of_CHPD)-1,5,'',cell_format)
                                          
                                          full_data1 = []
                                          full_data2 = []
                                          full_data3 = []
                                          full_data0 = 'v'.join(f[0])
                                          full_data1 = 'v'.join(f[1])
                                          full_data2 = 'v'.join(f[2])

                                          check_str = f[1][a]
                                          check_data2 = full_data1.partition(check_str)
                                          check_data3 = full_data2.partition(check_str)

                                          print(check_str, ' ch_str ',check_data2,' ch_d2',check_data3, 'ch_d3')
                                          #print(str(full_data2), 'fdfdf', check_data1, 'ch_d1')

                                          if check_data2[0] == '':
                                            if check_data2[2]=='':
                                              worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data2[1],cell_format_thin)
                                              worksheet3.write(o*int(num_of_CHPD)-3,3,full_data0,cell_format_thin)
                                            else:
                                              worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                              worksheet3.write(o*int(num_of_CHPD)-3,3,full_data0,cell_format_thin)
                                            if check_data3[0] == '':
                                              if check_data3[2] == '':
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data3[1],cell_format)
                                              else:
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data3[1],check_data3[2],cell_format)
                                            else:
                                              if check_data3[2] == '':
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,check_data3[0],red,check_data3[1],cell_format)
                                              else:
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format)
                                          else:
                                            if check_data2[2]=='':
                                              worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],cell_format_thin)
                                              worksheet3.write(o*int(num_of_CHPD)-3,3,full_data0,cell_format_thin)
                                            else:
                                              worksheet3.write_rich_string(o*int(num_of_CHPD)-2,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                                              worksheet3.write(o*int(num_of_CHPD)-3,3,full_data0,cell_format_thin)
                                            if check_data3[0] == '':
                                              if check_data3[2] == '':
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data3[1],cell_format)
                                              else:
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data3[1],check_data3[2],cell_format)
                                            else:
                                              if check_data3[2] == '':
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,check_data3[0],red,check_data3[1],cell_format)
                                              else:
                                                worksheet3.write_rich_string(o*int(num_of_CHPD)-1,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format)

                                          #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                          print(f[1][a],'   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                            #check_merge = 0
                            o+=1
                            f = f1.copy()
        if get_len_n3 != n3:
          o +=1                               
        # print(f)
        f=[]
        flag = True
workbook.close()

# %% [markdown]
# Union4.xlsx - ЧПД 4, вывод в test4.xlsx

# %%
#@title

workbook = xlsxwriter.Workbook('test4.xlsx')
worksheet4 = workbook.add_worksheet('For4')

red = workbook.add_format({ 'color': 'red'})

cell_format = workbook.add_format()
cell_format.set_bottom(2)
cell_format.set_left(1)
cell_format.set_right(1)
cell_format.set_align('center')
cell_format.set_align('vcenter')
cell_format.set_bg_color('#CCECFF')

cell_format_thin = workbook.add_format()
cell_format_thin.set_bottom(1)
cell_format_thin.set_left(1)
cell_format_thin.set_right(1)
cell_format_thin.set_align('center')
cell_format_thin.set_align('vcenter')
cell_format_thin.set_bg_color('#CCECFF')

cell_format_green_thin = workbook.add_format()
cell_format_green_thin.set_bottom(1)
cell_format_green_thin.set_left(1)
cell_format_green_thin.set_right(1)
cell_format_green_thin.set_align('center')
cell_format_green_thin.set_align('vcenter')
cell_format_green_thin.set_bg_color('#92D050')

cell_format_green = workbook.add_format()
cell_format_green.set_bottom(2)
cell_format_green.set_left(1)
cell_format_green.set_right(1)
cell_format_green.set_align('center')
cell_format_green.set_align('vcenter')
cell_format_green.set_bg_color('#92D050')

df1 = pd.read_excel('Union4.xlsx', sheet_name='Лист1',dtype = {'А': str})
df2 = pd.read_excel('Union4.xlsx', sheet_name='Лист2',dtype = {'А': str})
df3 = pd.read_excel('Union4.xlsx', sheet_name='Лист3',dtype = {'А': str})
num_of_CHPD = df1['ЧПД'][0]
n1 = df1['А'].count()
n2 = df2['А'].count()
n3 = df3['А'].count()
f=[]
f1 = []
flag = True
o=1
type(df1['ИБ'][0])
for i in range(0,n1):
    for j in range(0,n2):
        # print(i,' ', j)
        for p1 in range(0,int(num_of_CHPD)):
            split1=df1['ЗДП'][(i* num_of_CHPD)+p1].split("v")
            split2 = df2['ЗДП'][(j* num_of_CHPD)+p1].split("v")
            for item in split2: 
                   if item not in split1: 
                         split1.append(item)
            f.append(split1)
        
        check_merge = 0
        print('\n')
        print(f[0],'==Первая сумма==',f[1]) #Значения для периода перввой суммы
        # Для 3 и более периодов необходимо продублировать следующий for для всех пар f[i] f[i+1] до f[3] f[4], так чтобы количество внешних циклов for было на 1 меньше числа периодов
        for a in range(0,len(f[0])):
             for b in range(0,len(f[1])):
                 if f[0][a]==f[1][b]:
                      if check_merge != 1:
                          check_merge = 1
                          text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                          
                          pp = 'A' + str(o*int(num_of_CHPD)-3) + ':A' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, text, cell_format)
                          pp = 'B' + str(o*int(num_of_CHPD)-3) + ':B' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, ' - ', cell_format)
 
                      worksheet4.write(o*int(num_of_CHPD)-4,2,'1',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,2,'2',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,2,'3',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,2,'4',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)                      
                      worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                      full_data1 = 'v'.join(f[0])
                      full_data2 = 'v'.join(f[1])
                      full_data3 = 'v'.join(f[2])
                      full_data4 = 'v'.join(f[3])

                      check_str = f[0][a]
                      check_data1 = full_data1.partition(check_str)
                      check_data2 = full_data2.partition(check_str)

                      print(check_str, ' ch_str ',check_data1,' ch_d1',check_data2, 'ch_d2')
                      print(full_data3,'fd3',full_data4,'fd4',full_data2, 'fdfdf', check_data1, 'ch_d1')

                      if check_data1[0] == '':
                         if check_data1[2] =='':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data1[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data3,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data1[1],check_data1[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data3,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                         if check_data2[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                           if check_data2[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,' ',check_data2[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                         else:
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                           if check_data2[2] == '':
                             print('popalo')
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data2[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                      else:
                         if check_data1[2] =='':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data1[0],red,check_data1[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data3,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data1[0],red,check_data1[1],check_data1[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data3,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                         if check_data2[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                           if check_data2[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data2[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                         else:
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                           if check_data2[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,' ',check_data2[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)

                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[0][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
        for a in range(0,len(f[1])):
             for b in range(0,len(f[2])):
                 if f[1][a]==f[2][b]:
                      if check_merge != 1:
                          check_merge = 1
                          text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                          
                          pp = 'A' + str(o*int(num_of_CHPD)-3) + ':A' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, text, cell_format)
                          pp = 'B' + str(o*int(num_of_CHPD)-3) + ':B' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, ' - ', cell_format)
                      
                      worksheet4.write(o*int(num_of_CHPD)-4,2,'1',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,2,'2',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,2,'3',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,2,'4',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)                      
                      worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                      full_data1 = 'v'.join(f[0])
                      full_data2 = 'v'.join(f[1])
                      full_data3 = 'v'.join(f[2])
                      full_data4 = 'v'.join(f[3])

                      check_str = f[1][a]
                      check_data2 = full_data2.partition(check_str)
                      check_data3 = full_data3.partition(check_str)

                      print(check_str, ' ch_str ',check_data2,' ch_d2',check_data3, 'ch_d3')
                      print(full_data3,'fd3',full_data4,'fd4',full_data2, 'fd2', full_data1, 'fd1')

                      if check_data2[0] == '':
                         if check_data2[2] =='':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,' ',check_data2[1],cell_format_thin)
                           worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                           worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                         else:
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                           worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                           worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                         if check_data3[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],check_data3[2],cell_format_thin)
                           if check_data3[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                         else:
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                           if check_data3[2] == '':
                             print('meow')
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                      else:
                         if check_data2[2] =='':
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[0],check_data2[1],cell_format_thin)
                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                         else:
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                         if check_data3[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                           if check_data3[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                         else:
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                           if check_data3[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)

                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[1][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
        for a in range(0,len(f[2])):
             for b in range(0,len(f[3])):
                 if f[2][a]==f[3][b]:

                      if check_merge != 1:
                          check_merge = 1
                          text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                          
                          pp = 'A' + str(o*int(num_of_CHPD)-3) + ':A' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, text, cell_format)
                          pp = 'B' + str(o*int(num_of_CHPD)-3) + ':B' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, ' - ', cell_format)
                      
                      worksheet4.write(o*int(num_of_CHPD)-4,2,'1',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,2,'2',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,2,'3',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,2,'4',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)                      
                      worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                      full_data1 = 'v'.join(f[0])
                      full_data2 = 'v'.join(f[1])
                      full_data3 = 'v'.join(f[2])
                      full_data4 = 'v'.join(f[3])

                      check_str = f[2][a]
                      check_data3 = full_data3.partition(check_str)
                      check_data4 = full_data4.partition(check_str)

                      print(check_str, ' ch_str ',check_data3,' ch_d3',check_data4, 'ch_d4')
                      print(full_data3,'fd3',full_data4,'fd4',full_data2, 'fd2', full_data1, 'fd1')

                      if check_data3[0] == '':
                         if check_data3[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data2,cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data2,cell_format_thin)
                         if check_data4[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],check_data4[2],cell_format)
                           if check_data4[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],cell_format)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)
                         else:
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format)
                           if check_data4[2] == '':
                             print('meow')
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],cell_format)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)
                      else:
                         if check_data3[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data3[0],red,check_data3[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data2,cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data2,cell_format_thin)
                         if check_data4[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)
                           if check_data4[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],cell_format)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)
                         else:
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format)
                           if check_data4[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],cell_format)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)

                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[2][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
        get_len_n3 = 0
        f1 = f.copy()
        if flag:#Если первая сумма подошла
              for k in range(0,n3):
                          get_len_n3 +=1
                          if check_merge != 1:
                            #check_merge = 1
                            text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                            text_sum2 = str(df3['ИБ'][0]) + ' А' + str(df3['А'][k*num_of_CHPD])
                            
                            pp = 'A' + str(o*int(num_of_CHPD)-3) + ':A' + str((o*int(num_of_CHPD)))
                            worksheet4.merge_range(pp, text, cell_format)
                            pp = 'B' + str(o*int(num_of_CHPD)-3) + ':B' + str((o*int(num_of_CHPD)))
                            worksheet4.merge_range(pp, text_sum2, cell_format)
                          print(df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD], '====1ая подошла')
                          for p1 in range(0,int(num_of_CHPD)):
                              #f = f1.copy()
                              split3= df3['ЗДП'][(k* num_of_CHPD)+p1].split("v")
                              for item in range(0,len(f[p1])): 
                                    if f[p1][item] not in split3: 
                                          split3.append(f[p1][item])
                              #f[p1] = []
                              f[p1] = split3.copy()
                              print(f[p1],' Здесь находятся значения ', p1+1)#Здесь находятся значения для периода для двух сумм, номер периода находится в p1+1
                              full_data1 = 'v'.join(f[p1])
                              if p1 == 0:
                                print('popal v 1')
                                worksheet4.write(o*int(num_of_CHPD)-4,2,'1',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_green_thin)
                              elif p1 == 1:
                                print('popal v 2')
                                worksheet4.write(o*int(num_of_CHPD)-3,2,'2',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-3,3,full_data1,cell_format_green_thin)
                              elif p1 == 2:
                                print('popal v 3')
                                worksheet4.write(o*int(num_of_CHPD)-2,2,'3',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-2,3,full_data1,cell_format_green_thin)
                              else:
                                print('popal v 4',p1)
                                worksheet4.write(o*int(num_of_CHPD)-1,2,'4',cell_format_green)
                                worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format_green)
                                worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format_green)
                                worksheet4.write(o*int(num_of_CHPD)-1,3,full_data1,cell_format_green)
                          # print(f[0],'=====',f[1]) #Значения для периода перввой суммы
                          # Для 3 и более периодов необходимо продублировать следующий for для всех пар f[i] f[i+1] до f[3] f[4], так чтобы количество внешних циклов for было на 1 меньше числа периодов(почти тоже самое что и сверху)
                          for a in range(0,len(f[0])):
                              for b in range(0,len(f[1])):
                                  if f[0][a]==f[1][b]:

                                        worksheet4.write(o*int(num_of_CHPD)-4,2,'1',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,2,'2',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,2,'3',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,2,'4',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)                      
                                        worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                                        full_data1 = 'v'.join(f[0])
                                        full_data2 = 'v'.join(f[1])
                                        full_data3 = 'v'.join(f[2])
                                        full_data4 = 'v'.join(f[3])

                                        check_str = f[0][a]
                                        check_data1 = full_data1.partition(check_str)
                                        check_data2 = full_data2.partition(check_str)

                                        print(check_str, ' ch_str ',check_data1,' ch_d1',check_data2, 'ch_d2')
                                        print(full_data3,'fd3',full_data4,'fd4',full_data2, 'fdfdf', check_data1, 'ch_d1')

                                        if check_data1[0] == '':
                                          if check_data1[2] =='':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data1[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data3,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data1[1],check_data1[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data3,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                                          if check_data2[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                            if check_data2[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,' ',check_data2[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                                            if check_data2[2] == '':
                                              print('popalo')
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data2[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                        else:
                                          if check_data1[2] =='':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data1[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data3,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data1[1],check_data1[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data3,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                                          if check_data2[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                            if check_data2[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data2[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                                            if check_data2[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,' ',check_data2[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)

                                        #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                        print(f[0][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                          for a in range(0,len(f[1])):
                              for b in range(0,len(f[2])):
                                  if f[1][a]==f[2][b]:

                                        worksheet4.write(o*int(num_of_CHPD)-4,2,'1',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,2,'2',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,2,'3',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,2,'4',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)                      
                                        worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                                        full_data1 = 'v'.join(f[0])
                                        full_data2 = 'v'.join(f[1])
                                        full_data3 = 'v'.join(f[2])
                                        full_data4 = 'v'.join(f[3])

                                        check_str = f[1][a]
                                        check_data2 = full_data2.partition(check_str)
                                        check_data3 = full_data3.partition(check_str)

                                        print(check_str, ' ch_str ',check_data2,' ch_d2',check_data3, 'ch_d3')
                                        print(full_data3,'fd3',full_data4,'fd4',full_data2, 'fd2', full_data1, 'fd1')

                                        if check_data2[0] == '':
                                          if check_data2[2] =='':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,' ',check_data2[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                                          if check_data3[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],check_data3[2],cell_format_thin)
                                            if check_data3[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                                            if check_data3[2] == '':
                                              print('meow')
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                        else:
                                          if check_data2[2] =='':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data2[0],check_data2[1],cell_format_thin)
                                              worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                                              worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                                          else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                                              worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                                              worksheet4.write(o*int(num_of_CHPD)-1,3,full_data4,cell_format)
                                          if check_data3[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                            if check_data3[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                                            if check_data3[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)

                                        #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                        print(f[1][a],'   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                          for a in range(0,len(f[2])):
                              for b in range(0,len(f[3])):
                                  if f[2][a]==f[3][b]:

                                        worksheet4.write(o*int(num_of_CHPD)-4,2,'1',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,2,'2',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,2,'3',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,2,'4',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)                      
                                        worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                                        full_data1 = 'v'.join(f[0])
                                        full_data2 = 'v'.join(f[1])
                                        full_data3 = 'v'.join(f[2])
                                        full_data4 = 'v'.join(f[3])

                                        check_str = f[2][a]
                                        check_data3 = full_data3.partition(check_str)
                                        check_data4 = full_data4.partition(check_str)

                                        print(check_str, ' ch_str ',check_data3,' ch_d3',check_data4, 'ch_d4')
                                        print(full_data3,'fd3',full_data4,'fd4',full_data2, 'fd2', full_data1, 'fd1')

                                        if check_data3[0] == '':
                                          if check_data3[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data3[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data2,cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data2,cell_format_thin)
                                          if check_data4[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],check_data4[2],cell_format)
                                            if check_data4[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],cell_format)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format)
                                            if check_data4[2] == '':
                                              print('meow')
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],cell_format)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)
                                        else:
                                          if check_data3[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data3[0],red,check_data3[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data2,cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data2,cell_format_thin)
                                          if check_data4[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)
                                            if check_data4[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],cell_format)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format)
                                            if check_data4[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' z ',red,check_data4[1],cell_format)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data4[1],check_data4[2],cell_format)

                                        #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                        print(f[2][a],'   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                          
                          o +=1 
                          f = f1.copy() 
        if get_len_n3 != n3:
          o +=1                                
        # print(f)
        f=[]
        flag = True
workbook.close()

# %% [markdown]
# Union5.xlsx - ЧПД 5, вывод в test5.xlsx

# %%
#@title
workbook = xlsxwriter.Workbook('test5.xlsx')
worksheet4 = workbook.add_worksheet('For5')

red = workbook.add_format({ 'color': 'red'})

cell_format = workbook.add_format()
cell_format.set_bottom(2)
cell_format.set_left(1)
cell_format.set_right(1)
cell_format.set_align('center')
cell_format.set_align('vcenter')
cell_format.set_bg_color('#CCECFF')

cell_format_thin = workbook.add_format()
cell_format_thin.set_bottom(1)
cell_format_thin.set_left(1)
cell_format_thin.set_right(1)
cell_format_thin.set_align('center')
cell_format_thin.set_align('vcenter')
cell_format_thin.set_bg_color('#CCECFF')

cell_format_green_thin = workbook.add_format()
cell_format_green_thin.set_bottom(1)
cell_format_green_thin.set_left(1)
cell_format_green_thin.set_right(1)
cell_format_green_thin.set_align('center')
cell_format_green_thin.set_align('vcenter')
cell_format_green_thin.set_bg_color('#92D050')

cell_format_green = workbook.add_format()
cell_format_green.set_bottom(2)
cell_format_green.set_left(1)
cell_format_green.set_right(1)
cell_format_green.set_align('center')
cell_format_green.set_align('vcenter')
cell_format_green.set_bg_color('#92D050')

df1 = pd.read_excel('Union5.xlsx', sheet_name='Лист1',dtype = {'А': str})
df2 = pd.read_excel('Union5.xlsx', sheet_name='Лист2',dtype = {'А': str})
df3 = pd.read_excel('Union5.xlsx', sheet_name='Лист3',dtype = {'А': str})
num_of_CHPD = df1['ЧПД'][0]
n1 = df1['А'].count()
n2 = df2['А'].count()
n3 = df3['А'].count()
f=[]
f1 = []
flag = True
get_len_n3 = 0
o=1
type(df1['ИБ'][0])
for i in range(0,n1):
    for j in range(0,n2):
        # print(i,' ', j)
        for p1 in range(0,int(num_of_CHPD)):
            split1=df1['ЗДП'][(i* num_of_CHPD)+p1].split("v")
            split2 = df2['ЗДП'][(j* num_of_CHPD)+p1].split("v")
            for item in split2: 
                   if item not in split1: 
                         split1.append(item)
            f.append(split1)
        
        check_merge = 0
        print('\n')
        print(f[0],'==Первая сумма==',f[1]) #Значения для периода перввой суммы
        # Для 3 и более периодов необходимо продублировать следующий for для всех пар f[i] f[i+1] до f[3] f[4], так чтобы количество внешних циклов for было на 1 меньше числа периодов
        for a in range(0,len(f[0])):
             for b in range(0,len(f[1])):
                 if f[0][a]==f[1][b]:

                      if check_merge != 1:
                          check_merge = 1
                          text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                          
                          pp = 'A' + str(o*int(num_of_CHPD)-4) + ':A' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, text, cell_format)
                          pp = 'B' + str(o*int(num_of_CHPD)-4) + ':B' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, ' - ', cell_format)
 
                      worksheet4.write(o*int(num_of_CHPD)-5,2,'1',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-4,2,'2',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,2,'3',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,2,'4',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,2,'5',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-5,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-5,5,'',cell_format_thin)                      
                      worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                      full_data1 = 'v'.join(f[0])
                      full_data2 = 'v'.join(f[1])
                      full_data3 = 'v'.join(f[2])
                      full_data4 = 'v'.join(f[3])
                      full_data5 = 'v'.join(f[4])

                      check_str = f[0][a]
                      check_data1 = full_data1.partition(check_str)
                      check_data2 = full_data2.partition(check_str)

                      print(check_str, ' ch_str ',check_data1,' ch_d1',check_data2, 'ch_d2')
                      print(full_data3,'fd3',full_data4,'fd4',full_data2, 'fdfdf', check_data1, 'ch_d1')

                      if check_data1[0] == '':
                         if check_data1[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-5,3,' ',red,check_data1[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-5,3,red,check_data1[1],check_data1[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         if check_data2[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],check_data2[2],cell_format_thin)
                           if check_data2[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                          if check_data2[2] == '':
                            print('meow')
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                          else:
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                      else:
                         if check_data1[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-5,3,check_data1[0],red,check_data1[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-5,3,check_data1[0],red,check_data1[1],check_data1[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         if check_data2[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                           if check_data2[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                          if check_data2[2] == '':
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                          else:
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)

                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[0][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
        for a in range(0,len(f[1])):
             for b in range(0,len(f[2])):
                 if f[1][a]==f[2][b]:
                      if check_merge != 1:
                          check_merge = 1
                          text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                          
                          pp = 'A' + str(o*int(num_of_CHPD)-4) + ':A' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, text, cell_format)
                          pp = 'B' + str(o*int(num_of_CHPD)-4) + ':B' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, ' - ', cell_format)
 
                      worksheet4.write(o*int(num_of_CHPD)-5,2,'1',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-4,2,'2',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,2,'3',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,2,'4',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,2,'5',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-5,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-5,5,'',cell_format_thin)                      
                      worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                      full_data1 = 'v'.join(f[0])
                      full_data2 = 'v'.join(f[1])
                      full_data3 = 'v'.join(f[2])
                      full_data4 = 'v'.join(f[3])
                      full_data5 = 'v'.join(f[4])

                      check_str = f[1][a]
                      check_data2 = full_data2.partition(check_str)
                      check_data3 = full_data3.partition(check_str)

                      if check_data2[0] == '':
                         if check_data2[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         if check_data3[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],check_data3[2],cell_format_thin)
                           if check_data3[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                          if check_data3[2] == '':
                            print('meow')
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                          else:
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                      else:
                         if check_data2[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data2[0],red,check_data2[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         if check_data3[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                           if check_data3[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                          if check_data3[2] == '':
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                          else:
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)

                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[1][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
        for a in range(0,len(f[2])):
             for b in range(0,len(f[3])):
                 if f[2][a]==f[3][b]:
                      if check_merge != 1:
                          check_merge = 1
                          text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                          
                          pp = 'A' + str(o*int(num_of_CHPD)-4) + ':A' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, text, cell_format)
                          pp = 'B' + str(o*int(num_of_CHPD)-4) + ':B' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, ' - ', cell_format)
 
                      worksheet4.write(o*int(num_of_CHPD)-5,2,'1',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-4,2,'2',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,2,'3',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,2,'4',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,2,'5',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-5,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-5,5,'',cell_format_thin)                      
                      worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                      full_data1 = 'v'.join(f[0])
                      full_data2 = 'v'.join(f[1])
                      full_data3 = 'v'.join(f[2])
                      full_data4 = 'v'.join(f[3])
                      full_data5 = 'v'.join(f[4])

                      check_str = f[2][a]
                      check_data3 = full_data3.partition(check_str)
                      
                      check_data4 = full_data4.partition(check_str)

                      print(check_str, ' ch_str ',check_data3,' ch_d3',check_data4, 'ch_d4')
                      print(full_data5,'fd5',full_data4,'fd4',full_data3, 'fd3', full_data2, 'fd2',full_data1, 'fd1',  check_data3, 'ch_d3',check_data4, 'ch_d4')

                      if check_data3[0] == '':
                         if check_data3[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         if check_data4[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],check_data4[2],cell_format_thin)
                           if check_data4[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format_thin)
                          if check_data4[2] == '':
                            print('meow')
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                          else:
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                      else:
                         if check_data3[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data3[0],red,check_data3[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                         if check_data4[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                           if check_data4[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format_thin)
                          if check_data4[2] == '':
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                          else:
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)

                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[2][a], '  ачибка  ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
        for a in range(0,len(f[3])):
             for b in range(0,len(f[4])):
                 if f[3][a]==f[4][b]:
                      if check_merge != 1:
                          check_merge = 1
                          text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                          
                          pp = 'A' + str(o*int(num_of_CHPD)-4) + ':A' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, text, cell_format)
                          pp = 'B' + str(o*int(num_of_CHPD)-4) + ':B' + str((o*int(num_of_CHPD)))
                          worksheet4.merge_range(pp, ' - ', cell_format)
 
                      worksheet4.write(o*int(num_of_CHPD)-5,2,'1',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-4,2,'2',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,2,'3',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,2,'4',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,2,'5',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-5,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                      worksheet4.write(o*int(num_of_CHPD)-5,5,'',cell_format_thin)                      
                      worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                      worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                      full_data1 = 'v'.join(f[0])
                      full_data2 = 'v'.join(f[1])
                      full_data3 = 'v'.join(f[2])
                      full_data4 = 'v'.join(f[3])
                      full_data5 = 'v'.join(f[4])

                      check_str = f[3][a]
                      check_data4 = full_data4.partition(check_str)
                      
                      check_data5 = full_data5.partition(check_str)

                      print(check_str, ' ch_str ',check_data4,' ch_d4',check_data5, 'ch_d5')
                      print(full_data5,'fd5',full_data4,'fd4',full_data3, 'fd3', full_data2, 'fd2',full_data1, 'fd1',  check_data4,' ch_d4',check_data5, 'ch_d5')

                      if check_data4[0] == '':
                         if check_data4[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                         if check_data5[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],check_data5[2],cell_format)
                           if check_data5[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],cell_format)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,check_data5[0],red,check_data5[1],check_data5[2],cell_format)
                          if check_data5[2] == '':
                            print('meow')
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],cell_format)
                          else:
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)
                      else:
                         if check_data4[2] == '':
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data4[0],red,check_data4[1],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                          worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                         if check_data5[0] == '':
                           worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)
                           if check_data5[2] == '':
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],cell_format)
                           else:
                             worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)
                         else:
                          worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,check_data5[0],red,check_data5[1],check_data5[2],cell_format)
                          if check_data5[2] == '':
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],cell_format)
                          else:
                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)
                      #Здесь надо сделать красную подсветку в выводе в эксель, первая сумма не подошла(по идее)
                      print(f[3][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],'- ====1ая не подошла')
                      flag = False
        get_len_n3 = 0
        f1 = f.copy()
        if flag:#Если первая сумма подошла
              for k in range(0,n3):
                          get_len_n3 +=1
                          if check_merge != 1:
                            #check_merge = 1
                            text = str(df1['ИБ'][0]) + ' А' + str(df1['А'][i*num_of_CHPD]) + ' + ' + str(df2['ИБ'][0]) + ' А' + str(df2['А'][j*num_of_CHPD])
                            text_sum2 = str(df3['ИБ'][0]) + ' А' + str(df3['А'][k*num_of_CHPD])
                            
                            pp = 'A' + str(o*int(num_of_CHPD)-4) + ':A' + str((o*int(num_of_CHPD)))
                            worksheet4.merge_range(pp, text, cell_format)
                            pp = 'B' + str(o*int(num_of_CHPD)-4) + ':B' + str((o*int(num_of_CHPD)))
                            worksheet4.merge_range(pp, text_sum2, cell_format)
                          print(df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD], '====1ая подошла')
                          for p1 in range(0,int(num_of_CHPD)):
                              #f1 = f.copy()
                              split3= df3['ЗДП'][(k* num_of_CHPD)+p1].split("v")
                              for item in range(0,len(f[p1])): 
                                    if f[p1][item] not in split3: 
                                          split3.append(f[p1][item])
                              #f[p1] = []
                              f[p1] = split3.copy()
                              print(f[p1],' ', p1+1)#Здесь находятся значения для периода для двух сумм, номер периода находится в p1+1
                              full_data1 = 'v'.join(f[p1])
                              if p1 == 0:
                                print('popal v 1')
                                worksheet4.write(o*int(num_of_CHPD)-5,2,'1',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-5,4,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-5,5,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_green_thin)
                              elif p1 == 1:
                                print('popal v 2')
                                worksheet4.write(o*int(num_of_CHPD)-4,2,'2',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-4,3,full_data1,cell_format_green_thin)
                              elif p1 == 2:
                                print('popal v 3')
                                worksheet4.write(o*int(num_of_CHPD)-3,2,'3',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-3,3,full_data1,cell_format_green_thin)
                              elif p1 == 3:
                                print('popal v 4',p1)
                                worksheet4.write(o*int(num_of_CHPD)-2,2,'4',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_green_thin)
                                worksheet4.write(o*int(num_of_CHPD)-2,3,full_data1,cell_format_green_thin)
                              else:
                                print('popal v 5',p1)
                                worksheet4.write(o*int(num_of_CHPD)-1,2,'5',cell_format_green)
                                worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format_green)
                                worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format_green)
                                worksheet4.write(o*int(num_of_CHPD)-1,3,full_data1,cell_format_green)
                          
                          # print(f[0],'=====',f[1]) #Значения для периода перввой суммы
                          # Для 3 и более периодов необходимо продублировать следующий for для всех пар f[i] f[i+1] до f[3] f[4], так чтобы количество внешних циклов for было на 1 меньше числа периодов(почти тоже самое что и сверху)
                          for a in range(0,len(f[0])):
                              for b in range(0,len(f[1])):
                                  if f[0][a]==f[1][b]:
                                        worksheet4.write(o*int(num_of_CHPD)-5,2,'1',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-4,2,'2',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,2,'3',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,2,'4',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,2,'5',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-5,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-5,5,'',cell_format_thin)                      
                                        worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                                        full_data1 = 'v'.join(f[0])
                                        full_data2 = 'v'.join(f[1])
                                        full_data3 = 'v'.join(f[2])
                                        full_data4 = 'v'.join(f[3])
                                        full_data5 = 'v'.join(f[4])

                                        check_str = f[0][a]
                                        check_data1 = full_data1.partition(check_str)
                                        check_data2 = full_data2.partition(check_str)

                                        print(check_str, ' ch_str ',check_data1,' ch_d1',check_data2, 'ch_d2')
                                        print(full_data3,'fd3',full_data4,'fd4',full_data2, 'fdfdf', check_data1, 'ch_d1')

                                        if check_data1[0] == '':
                                          if check_data1[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-5,3,' ',red,check_data1[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-5,3,red,check_data1[1],check_data1[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          if check_data2[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],check_data2[2],cell_format_thin)
                                            if check_data2[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                                            if check_data2[2] == '':
                                              print('meow')
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                        else:
                                          if check_data1[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-5,3,check_data1[0],red,check_data1[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-5,3,check_data1[0],red,check_data1[1],check_data1[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          if check_data2[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                            if check_data2[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                                            if check_data2[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                        #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                        print(f[0][a], '   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                          for a in range(0,len(f[1])):
                              for b in range(0,len(f[2])):
                                  if f[1][a]==f[2][b]:
                                        worksheet4.write(o*int(num_of_CHPD)-5,2,'1',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-4,2,'2',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,2,'3',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,2,'4',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,2,'5',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-5,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-5,5,'',cell_format_thin)                      
                                        worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                                        full_data1 = 'v'.join(f[0])
                                        full_data2 = 'v'.join(f[1])
                                        full_data3 = 'v'.join(f[2])
                                        full_data4 = 'v'.join(f[3])
                                        full_data5 = 'v'.join(f[4])

                                        check_str = f[1][a]
                                        check_data2 = full_data2.partition(check_str)
                                        check_data3 = full_data3.partition(check_str)

                                        if check_data2[0] == '':
                                          if check_data2[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,' ',red,check_data2[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,red,check_data2[1],check_data2[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          if check_data3[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],check_data3[2],cell_format_thin)
                                            if check_data3[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                                            if check_data3[2] == '':
                                              print('meow')
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                        else:
                                          if check_data2[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data2[0],red,check_data2[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-4,3,check_data2[0],red,check_data2[1],check_data2[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-2,3,full_data4,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          if check_data3[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                            if check_data3[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                                            if check_data3[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                        #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                        print(f[1][a],'   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                          for a in range(0,len(f[2])):
                              for b in range(0,len(f[3])):
                                  if f[2][a]==f[3][b]:
                                        worksheet4.write(o*int(num_of_CHPD)-5,2,'1',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-4,2,'2',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,2,'3',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,2,'4',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,2,'5',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-5,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-5,5,'',cell_format_thin)                      
                                        worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                                        full_data1 = 'v'.join(f[0])
                                        full_data2 = 'v'.join(f[1])
                                        full_data3 = 'v'.join(f[2])
                                        full_data4 = 'v'.join(f[3])
                                        full_data5 = 'v'.join(f[4])

                                        check_str = f[2][a]
                                        check_data3 = full_data3.partition(check_str)
                                        
                                        check_data4 = full_data4.partition(check_str)

                                        print(check_str, ' ch_str ',check_data3,' ch_d3',check_data4, 'ch_d4')
                                        print(full_data5,'fd5',full_data4,'fd4',full_data3, 'fd3', full_data2, 'fd2',full_data1, 'fd1',  check_data3, 'ch_d3',check_data4, 'ch_d4')

                                        if check_data3[0] == '':
                                          if check_data3[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,' ',red,check_data3[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,red,check_data3[1],check_data3[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          if check_data4[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],check_data4[2],cell_format_thin)
                                            if check_data4[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format_thin)
                                            if check_data4[2] == '':
                                              print('meow')
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                                        else:
                                          if check_data3[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data3[0],red,check_data3[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-3,3,check_data3[0],red,check_data3[1],check_data3[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-1,3,full_data5,cell_format)
                                          if check_data4[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                                            if check_data4[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format_thin)
                                            if check_data4[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)

                                        #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                        print(f[2][a],'   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                          for a in range(0,len(f[3])):
                              for b in range(0,len(f[4])):
                                  if f[3][a]==f[4][b]:
                                        worksheet4.write(o*int(num_of_CHPD)-5,2,'1',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-4,2,'2',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,2,'3',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,2,'4',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,2,'5',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-5,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-4,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,4,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,4,'',cell_format)
                                        worksheet4.write(o*int(num_of_CHPD)-5,5,'',cell_format_thin)                      
                                        worksheet4.write(o*int(num_of_CHPD)-4,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-3,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-2,5,'',cell_format_thin)
                                        worksheet4.write(o*int(num_of_CHPD)-1,5,'',cell_format)

                                        full_data1 = 'v'.join(f[0])
                                        full_data2 = 'v'.join(f[1])
                                        full_data3 = 'v'.join(f[2])
                                        full_data4 = 'v'.join(f[3])
                                        full_data5 = 'v'.join(f[4])

                                        check_str = f[3][a]
                                        check_data4 = full_data4.partition(check_str)
                                        
                                        check_data5 = full_data5.partition(check_str)

                                        print(check_str, ' ch_str ',check_data4,' ch_d4',check_data5, 'ch_d5')
                                        print(full_data5,'fd5',full_data4,'fd4',full_data3, 'fd3', full_data2, 'fd2',full_data1, 'fd1',  check_data4,' ch_d4',check_data5, 'ch_d5')

                                        if check_data4[0] == '':
                                          if check_data4[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,' ',red,check_data4[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,red,check_data4[1],check_data4[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                                          if check_data5[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],check_data5[2],cell_format)
                                            if check_data5[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],cell_format)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,check_data5[0],red,check_data5[1],check_data5[2],cell_format)
                                            if check_data5[2] == '':
                                              print('meow')
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],cell_format)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)
                                        else:
                                          if check_data4[2] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data4[0],red,check_data4[1],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-2,3,check_data4[0],red,check_data4[1],check_data4[2],cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-5,3,full_data1,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-4,3,full_data2,cell_format_thin)
                                            worksheet4.write(o*int(num_of_CHPD)-3,3,full_data3,cell_format_thin)
                                          if check_data5[0] == '':
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)
                                            if check_data5[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],cell_format)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)
                                          else:
                                            worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,check_data5[0],red,check_data5[1],check_data5[2],cell_format)
                                            if check_data5[2] == '':
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,' ',red,check_data5[1],cell_format)
                                            else:
                                              worksheet4.write_rich_string(o*int(num_of_CHPD)-1,3,red,check_data5[1],check_data5[2],cell_format)

                                        #Здесь надо сделать красную подсветку в выводе в эксель, вторая сумма не подошла(по идее)
                                        print(f[3][a],'   ',df1['ИБ'][0],' А',df1['А'][i*num_of_CHPD],' + ',df2['ИБ'][0],' А',df2['А'][j*num_of_CHPD],' + ',df3['ИБ'][0],' А',df3['А'][k*num_of_CHPD],'- ====2ая не подошла')#Если пересечений много выведется много раз
                          
                          o +=1  
                          f = f1.copy()
        if get_len_n3 != n3:
            o +=1                                
        # print(f)
        f=[]
        flag = True
workbook.close()
# Out:
# ['[0.3]', '[0.1]'] ==Первая сумма== ['[0.5]', '[0.7]']
# ИБ1  А 5.1  +  ИБ2  А 5.1  +  ИБ3  А 5.1 ====1ая подошла
# ['[0.3]', '[0.1]']   1
# popal v 1
# ['[0.5]', '[0.7]']   2
# popal v 2
# ['[1.2]', '[1.1]']   3
# popal v 3
# ['[2.0]', '[3.1]']   4
# popal v 4 3
# ['[6.0]', '[5.2]', '[4.7]', '[6.2]']   5
# popal v 5 4
#
#
# ['[0.3]', '[0.1]'] ==Первая сумма== ['[0.5]', '[0.7]']
# ИБ1  А 5.1  +  ИБ2  А 5.2  +  ИБ3  А 5.1 ====1ая подошла
# ['[0.3]', '[0.1]']   1
# popal v 1
# ['[0.5]', '[0.7]']   2
# popal v 2
# ['[1.2]', '[1.1]']   3
# popal v 3
# ['[2.0]', '[3.1]', '[4.7]']   4
# popal v 4 3
# ['[6.0]', '[5.2]', '[6.2]']   5
# popal v 5 4
#
#
# ['[0.3]', '[0.1]'] ==Первая сумма== ['[0.5]', '[0.7]']
# [3.1]  ch_str  ('[1.2]v[1.1]v', '[3.1]', '')  ch_d3 ('', '[3.1]', 'v[4.7]') ch_d4
# [5.2]v[6.2] fd5 [3.1]v[4.7] fd4 [1.2]v[1.1]v[3.1] fd3 [0.5]v[0.7] fd2 [0.3]v[0.1] fd1 ('[1.2]v[1.1]v', '[3.1]', '') ch_d3 ('', '[3.1]', 'v[4.7]') ch_d4
# ...
